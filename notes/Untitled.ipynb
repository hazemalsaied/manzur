# %%
import pandas as pd

# %%
tags = pd.read_pickle('/home/hazem/Projects/manzur/data/pickles/enabbaladi/tags.pkl')

# %%
tags
# Out:
#                                                   _links  count description  \
# 0      {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 1      {'self': [{'href': 'https://enabbaladi.net/wp-...    0.0
# 2      {'self': [{'href': 'https://enabbaladi.net/wp-...    9.0
# 3      {'self': [{'href': 'https://enabbaladi.net/wp-...    5.0
# 4      {'self': [{'href': 'https://enabbaladi.net/wp-...    6.0
# ...                                                  ...    ...         ...
# 39985  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 39986  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 39987  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 39988  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 39989  {'self': [{'href': 'https://enabbaladi.net/wp-...   42.0
#
#             id                                               link meta  \
# 0      64842.0          https://enabbaladi.net/archives/tag/64842   []
# ...

# %%
import pickle
idx = 0
for i in range(0, len(tags), 5000):
    print(i)
    tags[i: i+5000 if i+5000 <len(tags) else len(tags)].to_pickle(f'tag_{idx}.pkl')
    idx += 1
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000

# %%
pd.read_pickle('ca.pkl')
# Out:
#                                                   _links  count description  \
# 35000  {'self': [{'href': 'https://enabbaladi.net/wp-...    4.0
# 35001  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 35002  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 35003  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 35004  {'self': [{'href': 'https://enabbaladi.net/wp-...    0.0
# ...                                                  ...    ...         ...
# 39985  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 39986  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 39987  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 39988  {'self': [{'href': 'https://enabbaladi.net/wp-...    1.0
# 39989  {'self': [{'href': 'https://enabbaladi.net/wp-...   42.0
#
#             id                                               link meta  \
# 35000  32810.0  https://enabbaladi.net/archives/tag/%d8%a7%d9%...   []
# ...
